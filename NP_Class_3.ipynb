# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitabhatkar35-creator/Data-Visualization/blob/main/NP_Class_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Create a list and perform a diiferent operation on it**

# %%
list=[1,2,3,4,5,6]
print(list)


list1=[1,"Pranita",2.8,True]
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 'Pranita', 2.8, True]

# %% [markdown]
# **Operation perform on list**

# %%
a=[1,2,3]
b=[4,5,6]
print(a+b)
print(a*2)
print(a*3)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# **Create a array**

# %%
import numpy as np

arr=np.array([1,2,3,4,5,6])
print(arr)
# Out:
# [1 2 3 4 5 6]

# %% [markdown]
# **Perform a different operation on array**

# %%
a=np.array([1,2,3,])
b=np.array([4,5,6])
print(a+b)
print(a-b)
print(a*b)
# Out:
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]

# %%
print(a/b)
print(a//b)
# Out:
# [0.25 0.4  0.5 ]
# [0 0 0]
